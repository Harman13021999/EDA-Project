# %%
# Useful Libraries being imported.
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Just a overview of the data.
df1 = pd.read_csv("C:/Users/Harman/Downloads/Datasets/deaths.csv")
df1.head()
# Out:
#         Entity Code  Year Number of executions (Amnesty International)  \
# 0  Afghanistan  AFG  2007                                           15
# 1  Afghanistan  AFG  2008                                           17
# 2  Afghanistan  AFG  2009                                            0
# 3  Afghanistan  AFG  2011                                            2
# 4  Afghanistan  AFG  2012                                           14
#
#    Deaths - Meningitis - Sex: Both - Age: All Ages (Number)  \
# 0                                             2933.0
# 1                                             2731.0
# 2                                             2460.0
# 3                                             2327.0
# 4                                             2254.0
#
#    Deaths - Alzheimer's disease and other dementias - Sex: Both - Age: All Ages (Number)  \
# 0                                             1402.0
# 1                                             1424.0
# ...

# %%
# Changing column names for more precise analysis.
df1.columns = ['Country', 'Country_Code', 'Year', 'Deaths_By_Execution', 'Deaths_By_Meningitis', 'Deaths_By_Alzheimer', 'Deaths_By_Parkinson', 'Deaths_By_Nutritional_Deficiencies', 'Deaths_By_Malaria', 'Deaths_By_Drowning', 'Deaths_By_Interpersonal_Violence', 'Deaths_By_Maternal_Disorders', 
              'Deaths_By_HIV', 'Deaths_By_Drugs', 'Deaths_By_Tuberculosis', 'Deaths_By_Cardiovascular_Diseases', 'Deaths_By_Lower_Respiratory_Infections', 'Deaths_By_Neonatal_Disorders', 'Deaths_By_Alcohol', 'Deaths_By_Selfharm', 
              'Deaths_By_Natural_Forces', 'Deaths_By_Diarrheal_Diseases', 'Deaths_By_Weather_Extremities', 'Deaths_By_Neoplasms', 'Deaths_By_Conflicts', 'Deaths_By_Diabetes', 'Deaths_By_Chronic_Kidney_Disease', 'Deaths_By_Poisonings', 'Deaths_By_Protein_Energy_Malnutrition', 'Deaths_By_Terrorism', 'Deaths_By_Road_Injuries ', 
              'Deaths_By_Chronic_Respiratory_Diseases ', 'Deaths_By_Cirrhosis_And_Chronic_Liver_Diseases', 'Deaths_By_Digestive_Diseases', 'Deaths_By_Fire', 'Deaths_By_Acute_Hepatitis']

# %%
# Data Cleaning

# England had missing country code so to fill up the country code with ENG string.
df1.loc[df1['Country'] == 'England','Country_Code'] = 'ENG'
df1.loc[df1['Country'] == 'England']
# Out:
#       Country Country_Code  Year Deaths_By_Execution  Deaths_By_Meningitis  \
# 1935  England          ENG  1990                 NaN                 446.0
# 1936  England          ENG  1991                 NaN                 442.0
# 1937  England          ENG  1992                 NaN                 395.0
# 1938  England          ENG  1993                 NaN                 398.0
# 1939  England          ENG  1994                 NaN                 392.0
# 1940  England          ENG  1995                 NaN                 409.0
# 1941  England          ENG  1996                 NaN                 420.0
# 1942  England          ENG  1997                 NaN                 420.0
# 1943  England          ENG  1998                 NaN                 415.0
# 1944  England          ENG  1999                 NaN                 408.0
# 1945  England          ENG  2000                 NaN                 394.0
# ...

# %%
# Removing the Country whose value is a Continent name or Region name.
df1.dropna(subset = ['Country_Code'], inplace = True)

# %%
# The following query removes particular rows from the Country column. 
df1.drop(df1.index[df1['Country'] == 'World'], inplace=True)
df1.drop(df1.index[df1['Country'] == 'Western Sahara'], inplace=True)

# %%
# Removing the Nan Values messed up the indexes so resetting the indexes.
df1.reset_index(drop = True, inplace = True)

# %%
# Replacing Nan values with 0 of a particular column.
df1.fillna({'Deaths_By_Execution':'0'},  inplace = True)

# %%
# Replacing Nan values with 0 for whole dataframe. 
df1.fillna(value=0, inplace=True)

# %%
# Changing the data type of column with float64 to int64.
for column in df1.columns:
    if df1[column].dtype == 'float64':
        df1[column] = df1[column].astype('int64')

# %%
df1.head(100)
# Out:
#            Country Country_Code  Year Deaths_By_Execution  \
# 0      Afghanistan          AFG  2007                  15
# 1      Afghanistan          AFG  2008                  17
# 2      Afghanistan          AFG  2009                   0
# 3      Afghanistan          AFG  2011                   2
# 4      Afghanistan          AFG  2012                  14
# 5      Afghanistan          AFG  2013                   2
# 6      Afghanistan          AFG  2014                   6
# 7      Afghanistan          AFG  2015                   1
# 8      Afghanistan          AFG  2016                   6
# 9      Afghanistan          AFG  1990                   0
# 10     Afghanistan          AFG  1991                   0
# 11     Afghanistan          AFG  1992                   0
# 12     Afghanistan          AFG  1993                   0
# 13     Afghanistan          AFG  1994                   0
# 14     Afghanistan          AFG  1995                   0
# ...

# %%
# The following query shows the total deaths by terrorism in each country since 1990.
df3 = df1.groupby(by="Country").Deaths_By_Terrorism.sum()
df4 = df3.to_frame()
df4.reset_index(inplace = True)
df4
# Out:
#                               Country  Deaths_By_Terrorism
# 0                         Afghanistan                39193
# 1                             Albania                   42
# 2                             Algeria                11066
# 3                      American Samoa                    0
# 4                             Andorra                    0
# 5                              Angola                 2195
# 6                 Antigua and Barbuda                    0
# 7                           Argentina                  125
# 8                             Armenia                   37
# 9                           Australia                   16
# 10                            Austria                    9
# 11                         Azerbaijan                  258
# 12                            Bahamas                    1
# 13                            Bahrain                   44
# 14                         Bangladesh                  933
# ...

# %%
# Country with the most deaths by terrorism since 1990.
df4.loc[df4['Deaths_By_Terrorism'] == df4['Deaths_By_Terrorism'].max()]
# Out:
#    Country  Deaths_By_Terrorism
# 90    Iraq                78428

# %%
# GRAPH
df4.plot.line(x='Country', y='Deaths_By_Terrorism', figsize=(15,5))
df4.loc[df4['Deaths_By_Terrorism'] == df4['Deaths_By_Terrorism'].max()]
# Out:
#    Country  Deaths_By_Terrorism
# 90    Iraq                78428

# %%
# The following query shows the total deaths by CardioVascular diseases in each country since 1990.
df5 = df1.groupby(by="Country").Deaths_By_Cardiovascular_Diseases.sum()
df6 = df5.to_frame()
df6.reset_index(inplace = True)
df6.rename({'Deaths_By_Cardiovascular_Diseases': 'Total_Deaths_By_Cardiovascular_Diseases'}, axis=1, inplace=True)
df6.loc[df6['Total_Deaths_By_Cardiovascular_Diseases'] == df6['Total_Deaths_By_Cardiovascular_Diseases'].max()]
df6
# Out:
#                               Country  Total_Deaths_By_Cardiovascular_Diseases
# 0                         Afghanistan                                  1607042
# 1                             Albania                                   270603
# 2                             Algeria                                  2123720
# 3                      American Samoa                                     2851
# 4                             Andorra                                     3526
# 5                              Angola                                   525047
# 6                 Antigua and Barbuda                                     5264
# 7                           Argentina                                  2836128
# 8                             Armenia                                   388635
# 9                           Australia                                  1441279
# 10                            Austria                                  1031672
# ...

# %%
# Country with the most deaths by CardioVascular Diseases since 1990.
df6.loc[df6['Total_Deaths_By_Cardiovascular_Diseases'] == df6['Total_Deaths_By_Cardiovascular_Diseases'].max()]
# Out:
#    Country  Total_Deaths_By_Cardiovascular_Diseases
# 37   China                                100505973

# %%
# GRAPH
df6.plot.line(x='Country', y='Total_Deaths_By_Cardiovascular_Diseases', figsize=(15,5))
df6.loc[df6['Total_Deaths_By_Cardiovascular_Diseases'] == df6['Total_Deaths_By_Cardiovascular_Diseases'].max()]
# Out:
#    Country  Total_Deaths_By_Cardiovascular_Diseases
# 37   China                                100505973

# %%
# Filtering out all the countries in Asia.

Asia = df1.loc[  (df1['Country'] == 'China') | (df1['Country'] == 'India') | (df1['Country'] == 'Indonesia') | (df1['Country'] == 'Pakistan')
        | (df1['Country'] == 'Bangladesh') | (df1['Country'] == 'Japan') | (df1['Country'] == 'Philippines') | (df1['Country'] == 'Vietnam')
        | (df1['Country'] == 'Turkey') | (df1['Country'] == 'Iran') | (df1['Country'] == 'Thailand') | (df1['Country'] == 'Myanmar')
        | (df1['Country'] == 'South Korea') | (df1['Country'] == 'Iraq') | (df1['Country'] == 'Afghanistan') | (df1['Country'] == 'Saudi Arabia')
        | (df1['Country'] == 'Uzbekistan') | (df1['Country'] == 'Malaysia') | (df1['Country'] == 'Yemen') | (df1['Country'] == 'Nepal')
        | (df1['Country'] == 'North Korea') | (df1['Country'] == 'Sri Lanka') | (df1['Country'] == 'Kazakhstan') | (df1['Country'] == 'Syria')
        | (df1['Country'] == 'Cambodia') | (df1['Country'] == 'Jordan') | (df1['Country'] == 'Azerbaijan') | (df1['Country'] == 'United Arab Emirates')
        | (df1['Country'] == 'Tajikistan') | (df1['Country'] == 'Israel') | (df1['Country'] == 'Laos') | (df1['Country'] == 'Lebanon')
        | (df1['Country'] == 'Kyrgyzstan') | (df1['Country'] == 'Turkmenistan') | (df1['Country'] == 'Singapore') | (df1['Country'] == 'Oman')
        | (df1['Country'] == 'Palestine') | (df1['Country'] == 'Kuwait') | (df1['Country'] == 'Georgia') | (df1['Country'] == 'Mongolia')
        | (df1['Country'] == 'Armenia') | (df1['Country'] == 'Qatar') | (df1['Country'] == 'Bahrain') | (df1['Country'] == 'Timor-Leste')
        | (df1['Country'] == 'Cyprus') | (df1['Country'] == 'Bhutan') | (df1['Country'] == 'Maldives') | (df1['Country'] == 'Brunei')
        | (df1['Country'] == 'Taiwan') | (df1['Country'] == 'Macao') | (df1['Country'] == 'Hong Kong')]

Asia.reset_index(inplace=True)

# %%
# Filtering out all the countries in Europe.

Europe = df1.loc[  (df1['Country'] == 'Russia') | (df1['Country'] == 'Germany') | (df1['Country'] == 'United Kingdom') | (df1['Country'] == 'France')
        | (df1['Country'] == 'Italy') | (df1['Country'] == 'Spain') | (df1['Country'] == 'Ukraine') | (df1['Country'] == 'Poland')
        | (df1['Country'] == 'Romania') | (df1['Country'] == 'Netherlands') | (df1['Country'] == 'Belgium') | (df1['Country'] == 'Czech Republic')
        | (df1['Country'] == 'Greece') | (df1['Country'] == 'Portugal') | (df1['Country'] == 'Sweden') | (df1['Country'] == 'Hungary')
        | (df1['Country'] == 'Belarus') | (df1['Country'] == 'Austria') | (df1['Country'] == 'Serbia') | (df1['Country'] == 'Switzerland')
        | (df1['Country'] == 'Bulgaria') | (df1['Country'] == 'Denmark') | (df1['Country'] == 'Finland') | (df1['Country'] == 'Slovakia')
        | (df1['Country'] == 'Norway') | (df1['Country'] == 'Ireland') | (df1['Country'] == 'Croatia') | (df1['Country'] == 'Moldova')
        | (df1['Country'] == 'Bosnia and Herzegovina') | (df1['Country'] == 'Albania') | (df1['Country'] == 'Lithuania') | (df1['Country'] == 'North Macedonia')
        | (df1['Country'] == 'Slovenia') | (df1['Country'] == 'Latvia') | (df1['Country'] == 'Estonia') | (df1['Country'] == 'Montenegro')
        | (df1['Country'] == 'Luxembourg') | (df1['Country'] == 'Malta') | (df1['Country'] == 'Iceland') | (df1['Country'] == 'Andorra')
        | (df1['Country'] == 'Monaco') | (df1['Country'] == 'Liechtenstein') | (df1['Country'] == 'San Marino') | (df1['Country'] == 'Holy See')
        | (df1['Country'] == 'Channel Islands') | (df1['Country'] == 'Isle of Man') | (df1['Country'] == 'Faeroe Islands') | (df1['Country'] == 'Gibraltar')]

Europe.reset_index(inplace=True)

# %%
# Filtering out all the countries in Africa.

Africa = df1.loc[  (df1['Country'] == 'Nigeria') | (df1['Country'] == 'Ethiopia') | (df1['Country'] == 'Egypt') | (df1['Country'] == 'Congo')
        | (df1['Country'] == 'Tanzania') | (df1['Country'] == 'South Africa') | (df1['Country'] == 'Kenya') | (df1['Country'] == 'Uganda')
        | (df1['Country'] == 'Algeria') | (df1['Country'] == 'Sudan') | (df1['Country'] == 'Morocco') | (df1['Country'] == 'Angola')
        | (df1['Country'] == 'Mozambique') | (df1['Country'] == 'Ghana') | (df1['Country'] == 'Madagascar') | (df1['Country'] == 'Cameroon')
        | (df1['Country'] == 'Cote d Ivoire') | (df1['Country'] == 'Niger') | (df1['Country'] == 'Burkina Faso') | (df1['Country'] == 'Mali')
        | (df1['Country'] == 'Malawi') | (df1['Country'] == 'Zambia') | (df1['Country'] == 'Senegal') | (df1['Country'] == 'Chad')
        | (df1['Country'] == 'Somalia') | (df1['Country'] == 'Zimbabwe') | (df1['Country'] == 'Guinea') | (df1['Country'] == 'Rwanda')
        | (df1['Country'] == 'Benin') | (df1['Country'] == 'Burundi') | (df1['Country'] == 'Tunisia') | (df1['Country'] == 'South Sudan')
        | (df1['Country'] == 'Togo') | (df1['Country'] == 'Sierra Leone') | (df1['Country'] == 'Libya') | (df1['Country'] == 'Liberia')
        | (df1['Country'] == 'Central African Republic') | (df1['Country'] == 'Mauritania') | (df1['Country'] == 'Eritrea') | (df1['Country'] == 'Namibia')
        | (df1['Country'] == 'Gambia') | (df1['Country'] == 'Botswana') | (df1['Country'] == 'Gabon') | (df1['Country'] == 'Lesotho')
        | (df1['Country'] == 'Guinea-Bissau') | (df1['Country'] == 'Equatorial Guinea') | (df1['Country'] == 'Mauritius') | (df1['Country'] == 'Eswatini')
        | (df1['Country'] == 'Djibouti') | (df1['Country'] == 'Comoros') | (df1['Country'] == 'Cabo Verde') | (df1['Country'] == 'Sao Tome & Principe')
        | (df1['Country'] == 'Seychelles') | (df1['Country'] == 'Réunion') | (df1['Country'] == 'Mayotte') | (df1['Country'] == 'Saint Helena')]


Africa.reset_index(inplace=True)

# %%
# Filtering out all the countries in America.

America = df1.loc[  (df1['Country'] == 'United States') | (df1['Country'] == 'Brazil') | (df1['Country'] == 'Mexico') | (df1['Country'] == 'Colombia')
               | (df1['Country'] == 'Argentina') | (df1['Country'] == 'Canada') | (df1['Country'] == 'Peru') | (df1['Country'] == 'Venezuela')
               | (df1['Country'] == 'Chile') | (df1['Country'] == 'Guatemala') | (df1['Country'] == 'Ecuador') | (df1['Country'] == 'Bolivia')
               | (df1['Country'] == 'Haiti') | (df1['Country'] == 'Cuba') | (df1['Country'] == 'Dominican Republic') | (df1['Country'] == 'Honduras')
               | (df1['Country'] == 'Paraguay') | (df1['Country'] == 'Nicaragua') | (df1['Country'] == 'El Salvador') | (df1['Country'] == 'Costa Rica')
               | (df1['Country'] == 'Panama') | (df1['Country'] == 'Uruguay') | (df1['Country'] == 'Jamaica') | (df1['Country'] == 'Trinidad And Tobago')
               | (df1['Country'] == 'Guyana') | (df1['Country'] == 'Suriname') | (df1['Country'] == 'Belize') | (df1['Country'] == 'Bahamas')
               | (df1['Country'] == 'Barbados') | (df1['Country'] == 'Saint Lucia') | (df1['Country'] == 'Grenada') | (df1['Country'] == 'Saint Vincent And the Grenadines')
               | (df1['Country'] == 'Antigua And Barbuda') | (df1['Country'] == 'Dominica') | (df1['Country'] == 'Saint Kitts And Nevis')]

America.reset_index(inplace=True)

# %%
Asia_Data = [Asia['Deaths_By_Meningitis'].sum(), Asia['Deaths_By_Alzheimer'].sum(), Asia['Deaths_By_Parkinson'].sum(),
            Asia['Deaths_By_Malaria'].sum(), Asia['Deaths_By_HIV'].sum(), Asia['Deaths_By_Drugs'].sum(),
            Asia['Deaths_By_Tuberculosis'].sum(), Asia['Deaths_By_Cardiovascular_Diseases'].sum(), Asia['Deaths_By_Lower_Respiratory_Infections'].sum(),
            Asia['Deaths_By_Alcohol'].sum(), Asia['Deaths_By_Diabetes'].sum(), Asia['Deaths_By_Chronic_Kidney_Disease'].sum(),
            Asia['Deaths_By_Poisonings'].sum(), Asia['Deaths_By_Terrorism'].sum(),
            Asia['Deaths_By_Digestive_Diseases'].sum(), Asia['Deaths_By_Acute_Hepatitis'].sum()]

Alabels = ['Deaths_By_Meningitis', 'Deaths_By_Alzheimer', 'Deaths_By_Parkinson', 'Deaths_By_Malaria', 
          'Deaths_By_HIV', 'Deaths_By_Drugs', 'Deaths_By_Tuberculosis', 'Deaths_By_Cardiovascular_Diseases', 
          'Deaths_By_Lower_Respiratory_Infections', 'Deaths_By_Alcohol', 'Deaths_By_Diabetes', 'Deaths_By_Chronic_Kidney_Disease', 
          'Deaths_By_Poisonings', 'Deaths_By_Terrorism', 'Deaths_By_Digestive_Diseases', 'Deaths_By_Acute_Hepatitis']

a = pd.Series(Asia_Data, Alabels)
a = a.to_frame()
a.reset_index(inplace=True)
a.rename(columns = {'index':'Cause_of_Death', 0:'Number_of_Deaths'}, inplace = True)

# %%
Europe_Data = [Europe['Deaths_By_Meningitis'].sum(), Europe['Deaths_By_Alzheimer'].sum(), Europe['Deaths_By_Parkinson'].sum(),
            Europe['Deaths_By_Malaria'].sum(), Europe['Deaths_By_HIV'].sum(), Europe['Deaths_By_Drugs'].sum(),
            Europe['Deaths_By_Tuberculosis'].sum(), Europe['Deaths_By_Cardiovascular_Diseases'].sum(), Europe['Deaths_By_Lower_Respiratory_Infections'].sum(),
            Europe['Deaths_By_Alcohol'].sum(), Europe['Deaths_By_Diabetes'].sum(), Europe['Deaths_By_Chronic_Kidney_Disease'].sum(),
            Europe['Deaths_By_Poisonings'].sum(), Europe['Deaths_By_Terrorism'].sum(),
            Europe['Deaths_By_Digestive_Diseases'].sum(), Europe['Deaths_By_Acute_Hepatitis'].sum()]

Elabels = ['Deaths_By_Meningitis', 'Deaths_By_Alzheimer', 'Deaths_By_Parkinson', 'Deaths_By_Malaria', 
          'Deaths_By_HIV', 'Deaths_By_Drugs', 'Deaths_By_Tuberculosis', 'Deaths_By_Cardiovascular_Diseases', 
          'Deaths_By_Lower_Respiratory_Infections', 'Deaths_By_Alcohol', 'Deaths_By_Diabetes', 'Deaths_By_Chronic_Kidney_Disease', 
          'Deaths_By_Poisonings', 'Deaths_By_Terrorism', 'Deaths_By_Digestive_Diseases', 'Deaths_By_Acute_Hepatitis']

e = pd.Series(Europe_Data, Elabels)
e = e.to_frame()
e.reset_index(inplace=True)
e.rename(columns = {'index':'Cause_of_Death', 0:'Number_of_Deaths'}, inplace = True)

# %%
Africa_Data = [Africa['Deaths_By_Meningitis'].sum(), Africa['Deaths_By_Alzheimer'].sum(), Africa['Deaths_By_Parkinson'].sum(),
            Africa['Deaths_By_Malaria'].sum(), Africa['Deaths_By_HIV'].sum(), Africa['Deaths_By_Drugs'].sum(),
            Africa['Deaths_By_Tuberculosis'].sum(), Africa['Deaths_By_Cardiovascular_Diseases'].sum(), Africa['Deaths_By_Lower_Respiratory_Infections'].sum(),
            Africa['Deaths_By_Alcohol'].sum(), Africa['Deaths_By_Diabetes'].sum(), Africa['Deaths_By_Chronic_Kidney_Disease'].sum(),
            Africa['Deaths_By_Poisonings'].sum(), Africa['Deaths_By_Terrorism'].sum(),
            Africa['Deaths_By_Digestive_Diseases'].sum(), Africa['Deaths_By_Acute_Hepatitis'].sum()]

Aflabels = ['Deaths_By_Meningitis', 'Deaths_By_Alzheimer', 'Deaths_By_Parkinson', 'Deaths_By_Malaria', 
          'Deaths_By_HIV', 'Deaths_By_Drugs', 'Deaths_By_Tuberculosis', 'Deaths_By_Cardiovascular_Diseases', 
          'Deaths_By_Lower_Respiratory_Infections', 'Deaths_By_Alcohol', 'Deaths_By_Diabetes', 'Deaths_By_Chronic_Kidney_Disease', 
          'Deaths_By_Poisonings', 'Deaths_By_Terrorism', 'Deaths_By_Digestive_Diseases', 'Deaths_By_Acute_Hepatitis']

af = pd.Series(Africa_Data, Aflabels)
af = af.to_frame()
af.reset_index(inplace=True)
af.rename(columns = {'index':'Cause_of_Death', 0:'Number_of_Deaths'}, inplace = True)

# %%
America_Data = [America['Deaths_By_Meningitis'].sum(), America['Deaths_By_Alzheimer'].sum(), America['Deaths_By_Parkinson'].sum(),
            America['Deaths_By_Malaria'].sum(), America['Deaths_By_HIV'].sum(), America['Deaths_By_Drugs'].sum(),
            America['Deaths_By_Tuberculosis'].sum(), America['Deaths_By_Cardiovascular_Diseases'].sum(), America['Deaths_By_Lower_Respiratory_Infections'].sum(),
            America['Deaths_By_Alcohol'].sum(), America['Deaths_By_Diabetes'].sum(), America['Deaths_By_Chronic_Kidney_Disease'].sum(),
            America['Deaths_By_Poisonings'].sum(), America['Deaths_By_Terrorism'].sum(),
            America['Deaths_By_Digestive_Diseases'].sum(), America['Deaths_By_Acute_Hepatitis'].sum()]

Amlabels = ['Deaths_By_Meningitis', 'Deaths_By_Alzheimer', 'Deaths_By_Parkinson', 'Deaths_By_Malaria', 
          'Deaths_By_HIV', 'Deaths_By_Drugs', 'Deaths_By_Tuberculosis', 'Deaths_By_Cardiovascular_Diseases', 
          'Deaths_By_Lower_Respiratory_Infections', 'Deaths_By_Alcohol', 'Deaths_By_Diabetes', 'Deaths_By_Chronic_Kidney_Disease', 
          'Deaths_By_Poisonings', 'Deaths_By_Terrorism', 'Deaths_By_Digestive_Diseases', 'Deaths_By_Acute_Hepatitis']

am = pd.Series(America_Data, Amlabels)
am = am.to_frame()
am.reset_index(inplace=True)
am.rename(columns = {'index':'Cause_of_Death', 0:'Number_of_Deaths'}, inplace = True)

# %%
a.plot.line(x='Cause_of_Death', y='Number_of_Deaths', figsize=(27,10))
a.loc[a['Number_of_Deaths'] == a['Number_of_Deaths'].max()]
# Out:
#                       Cause_of_Death  Number_of_Deaths
# 7  Deaths_By_Cardiovascular_Diseases         240102988

# %%
e.plot.line(x='Cause_of_Death', y='Number_of_Deaths', figsize=(27,10))
e.loc[e['Number_of_Deaths'] == e['Number_of_Deaths'].max()]
# Out:
#                       Cause_of_Death  Number_of_Deaths
# 7  Deaths_By_Cardiovascular_Diseases         113131463

# %%
af.plot.line(x='Cause_of_Death', y='Number_of_Deaths', figsize=(27,10))
af.loc[af['Number_of_Deaths'] == af['Number_of_Deaths'].max()]
# Out:
#                       Cause_of_Death  Number_of_Deaths
# 7  Deaths_By_Cardiovascular_Diseases          34178398

# %%
am.plot.line(x='Cause_of_Death', y='Number_of_Deaths', figsize=(27,10))
am.loc[am['Number_of_Deaths'] == am['Number_of_Deaths'].max()]
# Out:
#                       Cause_of_Death  Number_of_Deaths
# 7  Deaths_By_Cardiovascular_Diseases          53476018

# %% [markdown]
# # From the above analysis, we can conclude that the no. 1 cause of deaths in every continent since 1990 are from CardioVascular diseases.
